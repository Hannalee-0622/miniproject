# %% [markdown]
# ## **오늘의 목표**
#
# - Hugging Face transformers 라이브러리로 텍스트 생성 사용법 이해
#
# - NLTK 사전 기반 단어 검증 이해
#
# - Gradio를 활용한 간단한 웹 앱 인터페이스 구축
#
# - 상태 기반 로직을 이해하고, 중복 방지 및 점수 시스템 구현

# %% [markdown]
# 1. 필요한 라이브러리들을 설치해주세요.
#
# ```!pip install transformers gradio nltk torch```

# %%
# !pip install transformers nltk
# Out:
# Requirement already satisfied: transformers in ./huggingface-env/lib/python3.11/site-packages (4.49.0)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: filelock in ./huggingface-env/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in ./huggingface-env/lib/python3.11/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in ./huggingface-env/lib/python3.11/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in ./huggingface-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./huggingface-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./huggingface-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (1.1.4)
# Requirement already satisfied: click in ./huggingface-env/lib/python3.11/site-packages (from nltk) (8.2.1)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./huggingface-env/lib/python3.11/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./huggingface-env/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./huggingface-env/lib/python3.11/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./huggingface-env/lib/python3.11/site-packages (from requests->transformers) (2025.6.15)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 32.5 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: joblib, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]1/2 [nltk]
# Successfully installed joblib-1.5.1 nltk-3.9.1

# %% [markdown]
# 2. ```nltk.download("words")``` 실행하여 english_vocab 변수를 확인하세요.

# %%
import nltk
from nltk.corpus import words

nltk.download("words")

english_vocab = set(words.words())

print(f"단어 수: {len(english_vocab)}")
print(list(english_vocab)[:10])
# Out:
# 단어 수: 235892
# ['genista', 'khediviah', 'unenraptured', 'tosticate', 'coolingly', 'Archelenis', 'divergent', 'heterochromatin', 'cartobibliography', 'unaccrued']
# [nltk_data] Downloading package words to /Users/hannalee/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# 3. 사용자로부터 단어를 입력받아 입력한 단어가 포함되어 있는지 확인하는 코드를 작성하세요.

# %%
word = "apple"

print(word in english_vocab)
# Out:
# True

# %% [markdown]
# 4. GPT로 간단하게 단어 생성 실습을 해보겠습니다.
# 간단한 프롬프트를 작성하여 문장을 생성해보세요.

# %%
from transformers import pipeline  
generator = pipeline("text-generation", model="distilgpt2")  
prompt = "Give me a single English word that starts with 's'."
output = generator(prompt, max_new_tokens=50, do_sample=True, temperature=0.8)[0]["generated_text"]
print("\n", output)
# Out:
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use mps:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /Users/hannalee/Documents/코딩/huggingface-env/lib/python3.11/site-packages/transformers/pytorch_utils.py:338: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_elements = torch.tensor(test_elements)
#  Give me a single English word that starts with 's'.
# You can also see where it comes from (by the way).
# I think it’s a nice move.
# Here’s how I explain it:
# I don’t know if there is a way to make English

# %% [markdown]
# 5. 위 결과를 토대로 한계점을 설명하겠습니다.
#
# </br>
#
# - **GPT-2 계열 (dustilgpt2)의 구조적 한계**
#
#     - ```distilgpt2```는 **GPT-2**의 경량화 모델로, 적은 파라미터 수로 인해 정확도와 문맥 추론 능력이 제한적입니다.
#
#     - 단어 하나만 정확히 생성하는 것보다는 문장이나 이야기 생성에 더 적합합니다.
#
# - **프롬프트 해석의 유연함**
#     - GPT 계열 모델은 **자유 생성(free generation)**을 기반으로 작동하므로,
#     ```"Give me a single English word..."``` 같은 요청을 보고도 리스트, 설명, 정의 등 다양한 방식으로 응답할 수 있습니다.
#
#     - 인간이라면 ```"s로 시작하는 단어: sun"```처럼 줄 텐데, 모델은 정답이 아니라 문장을 생성하는 데 집중합니다.
#
# - **정확한 제어가 어려움**
#     - ```text-generation``` 파이프라인은 **지시(command)** 수행보다는 자유 텍스트 생성에 적합합니다.
#
#     - "단어만 뽑기" 같은 작업은 ```text2text```나 ```fill-mask```, 또는 직접 후처리를 더한 커스텀 로직이 필요합니다.

# %% [markdown]
# 6. 모델을 여러 번 로드하기 때문에 로컬에 다운로드하여 사용하겠습니다.
# 지시 작업에 더 어울리는 flan-t5 계열의 모델을 다운로드하세요.

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "google/flan-t5-large"
local_path = "./models/flan-t5-large"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

tokenizer.save_pretrained(local_path)
model.save_pretrained(local_path)
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# 6-1. 다운로드가 완료된 모델을 ```mps```에 올린 뒤에 테스트를 진행해보세요.

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

device = 0 if torch.backends.mps.is_available() else -1

tokenizer = AutoTokenizer.from_pretrained(local_path)
model = AutoModelForSeq2SeqLM.from_pretrained(local_path).to("mps" if device == 0 else "cpu")

generator = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device=device)  
prompt = "Give me a single English word that starts with 's'."
output = generator(prompt, max_new_tokens=50, do_sample=True, temperature=0.8)[0]["generated_text"]
print("Result:", output)
# Out:
# Device set to use mps:0
# /Users/hannalee/Documents/코딩/huggingface-env/lib/python3.11/site-packages/transformers/pytorch_utils.py:338: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_elements = torch.tensor(test_elements)
# Result: symphony

# %% [markdown]
# 7. 원하는대로 결과가 나왔으니 끝말잇기 게임을 만들어보겠습니다. **UI**는 ```Gradio```를 활용하겠습니다.
# 먼저, 단어들을 다운로드하여 소문자로 전부 변경해주세요.

# %%
import gradio as gr
from transformers import pipeline
import re
import nltk
from nltk.corpus import words

english_vocab = set(w.lower() for w in words.words())
english_vocab
# Out:
# {'genista',
#  'khediviah',
#  'unenraptured',
#  'tosticate',
#  'coolingly',
#  'divergent',
#  'heterochromatin',
#  'cartobibliography',
#  'unaccrued',
#  'cion',
#  'glochid',
#  'anareta',
#  'quintocubitalism',
#  'trichology',
#  'unempirical',
#  'iriartea',
#  'trunkmaker',
#  'jakes',
#  'trophically',
#  'untemperamental',
#  'mesian',
#  'infern',
#  'harpullia',
#  'bonniness',
#  'recoverer',
#  'erythropoietic',
#  'evens',
#  'machineless',
#  'unmicrobic',
#  'overquantity',
#  'castrum',
#  'unobjective',
#  'xanthomelanous',
#  'pullable',
#  'sightfulness',
#  'incanton',
#  'prayerfully',
#  'bandless',
#  'overtame',
#  'nasofrontal',
#  'virgin',
#  'unimaginable',
#  'azobenzoic',
#  'hanging',
#  'obliquus',
#  'charleston',
#  'degeneralize',
#  'warsle',
#  'mastoid',
#  'vagodepressor',
#  'haydenite',
#  'fundiform',
#  'groomy',
#  'gaze',
#  'octary',
#  'inviolacy',
#  'imbarn',
#  'shravey',
#  'unrumored',
#  'yen',
#  'electrologic',
#  'proxy',
#  'suprafoliar',
#  'sawman',
#  'boatloading',
#  'inactively',
#  'endoceratitic',
#  'swimminess',
#  'supersaliency',
#  'macaco',
#  'farmable',
#  'domically',
#  'hyperstrophic',
#  'unode',
#  'weightlessness',
#  'uncreate',
#  'hearsay',
#  'gluteofemoral',
#  'remultiply',
#  'subfebrile',
#  'downfeed',
#  'panna',
#  'positionless',
#  'heaving',
#  'betterment',
#  'objurgate',
#  'theologic',
#  'thacker',
#  'dartle',
#  'thickhead',
#  'microconjugant',
#  'redfish',
#  'carbonite',
#  'blenny',
#  'halide',
#  'misconstitutional',
#  'unskilledly',
#  'thallus',
#  'vaginule',
#  'vitalizingly',
#  'blowball',
#  'tar',
#  'tressless',
#  'accompanyist',
#  'celtologist',
#  'depreciatingly',
#  'oribi',
#  'carinatae',
#  'vext',
#  'subscribership',
#  'outfool',
#  'retinasphaltum',
#  'reaggressive',
#  'peage',
#  'propitiatingly',
#  'inactuate',
#  'beadleship',
#  'agronome',
#  'bezesteen',
#  'moste',
#  'alveololabial',
#  'cesspool',
#  'chivalrousness',
#  'hyporhined',
#  'wharp',
#  'flagboat',
#  'thermoplastic',
#  'isacoustic',
#  'imbecilely',
#  'bugbearish',
#  'sunward',
#  'condensable',
#  'nondivergence',
#  'admitted',
#  'coreflexed',
#  'klamath',
#  'philathletic',
#  'telechemic',
#  'blinked',
#  'ginglymostoma',
#  'posing',
#  'blackbelly',
#  'misgovern',
#  'transferring',
#  'abdominocentesis',
#  'hayseed',
#  'ungraft',
#  'photogrammetrical',
#  'iridencleisis',
#  'pregustation',
#  'bruchidae',
#  'kowagmiut',
#  'refund',
#  'tertiate',
#  'highbinder',
#  'antefurca',
#  'tomahawk',
#  'cookhouse',
#  'metabolism',
#  'keten',
#  'trilaterality',
#  'tuberculoprotein',
#  'cyphonism',
#  'pacifical',
#  'sensed',
#  'prevocational',
#  'killcrop',
#  'hegemonic',
#  'milk',
#  'caoba',
#  'kiwanis',
#  'outsmart',
#  'pseudoscorpiones',
#  'endophytal',
#  'fumariaceae',
#  'interchangeably',
#  'perceptibly',
#  'titoist',
#  'trinacrian',
#  'misguidedness',
#  'fossilologist',
#  'sten',
#  'wokowi',
#  'attirement',
#  'antecedency',
#  'coastal',
#  'pastille',
#  'kiang',
#  'tipulid',
#  'venue',
#  'tuggery',
#  'ruru',
#  'osteonecrosis',
#  'theatricalization',
#  'undivinelike',
#  'hetaeric',
#  'quadratosquamosal',
#  'unsubjectlike',
#  'asthenical',
#  'negotiatory',
#  'maying',
#  'semiwaking',
#  'brachydont',
#  'metepencephalon',
#  'slampamp',
#  'kanthan',
#  'shag',
#  'abjudicate',
#  'lactation',
#  'hurtsome',
#  'lupeol',
#  'biophagism',
#  'incopresentability',
#  'tarnisher',
#  'heterization',
#  'fingall',
#  'subarian',
#  'asbolite',
#  'matai',
#  'conterminous',
#  'encinder',
#  'litterateur',
#  'cathayan',
#  'tetrabrach',
#  'frontierlike',
#  'heresyphobia',
#  'undevil',
#  'neuropsychiatry',
#  'guarabu',
#  'botryotherapy',
#  'vanman',
#  'fortnight',
#  'pharmacodynamics',
#  'ceraunoscopy',
#  'mermnad',
#  'convalescence',
#  'mislight',
#  'ipomoea',
#  'lealand',
#  'satinette',
#  'fasciola',
#  'interloculus',
#  'stomatopoda',
#  'fagelia',
#  'byway',
#  'dichroitic',
#  'facultatively',
#  'familiarly',
#  'bardulph',
#  'turncoatism',
#  'componendo',
#  'footlining',
#  'fumingly',
#  'armeria',
#  'ism',
#  'bearbaiter',
#  'untainted',
#  'stammering',
#  'trichinosed',
#  'splanchnocoele',
#  'mortifiedly',
#  'thermomotor',
#  'laccol',
#  'wangala',
#  'superacute',
#  'coupelet',
#  'grasshopperish',
#  'technocausis',
#  'manavel',
#  'extrinsicate',
#  'gangdom',
#  'heavenish',
#  'aeolsklavier',
#  'nomarthral',
#  'microsphere',
#  'viewer',
#  'specillum',
#  'elatinaceous',
#  'diplospondylism',
#  'miasmic',
#  'partless',
#  'sheepify',
#  'gulper',
#  'hypotrochanteric',
#  'squilgee',
#  'exhorter',
#  'ahmet',
#  'krzysztof',
#  'gul',
#  'nonrestrictive',
#  'buffer',
#  'bellow',
#  'cytoblastemal',
#  'imperceptible',
#  'preflattery',
#  'unballoted',
#  'goring',
#  'unbeneficent',
#  'unsensitize',
#  'untz',
#  'indexless',
#  'meritoriously',
#  'deficiently',
#  'peneplain',
#  'anatomicobiological',
#  'colipuncture',
#  'suffusable',
#  'divaricate',
#  'cattleyak',
#  'flindersia',
#  'pilgarlicky',
#  'shrups',
#  'dirty',
#  'triradially',
#  'decoction',
#  'esteriferous',
#  'antheriferous',
#  'pokeberry',
#  'cydonian',
#  'tach',
#  'pullboat',
#  'unmanful',
#  'nidificant',
#  'stretch',
#  'sibilous',
#  'enface',
#  'unretarded',
#  'standish',
#  'essayette',
#  'cheesecurd',
#  'unsupportableness',
#  'inestimability',
#  'penninerved',
#  'ramblingly',
#  'dishpanful',
#  'smartweed',
#  'stalactited',
#  'sporophore',
#  'occipitosphenoid',
#  'persecutory',
#  'hamiticized',
#  'fasher',
#  'biscayan',
#  'condolence',
#  'unobscene',
#  'rhizomorph',
#  'unfeasibleness',
#  'forging',
#  'hemitrichous',
#  'vauntiness',
#  'disorderliness',
#  'pseudohallucination',
#  'quackster',
#  'aethalioid',
#  'raad',
#  'salmonlike',
#  'semihexagonal',
#  'candys',
#  'lovability',
#  'geopolitics',
#  'piscian',
#  'triodontidae',
#  'aclemon',
#  'duchy',
#  'violentness',
#  'hoodwort',
#  'unelected',
#  'soteriological',
#  'epithalamy',
#  'periangitis',
#  'brandling',
#  'picariae',
#  'funis',
#  'australorp',
#  'barleyhood',
#  'mammutidae',
#  'rootless',
#  'septiferous',
#  'knickknack',
#  'autecologically',
#  'prisondom',
#  'provocatively',
#  'slavicism',
#  'tegeticula',
#  'frightable',
#  'development',
#  'grandee',
#  'allayer',
#  'linkage',
#  'unshelterable',
#  'nematocystic',
#  'goaf',
#  'hanky',
#  'underactor',
#  'upholsterer',
#  'cryosel',
#  'whistlerian',
#  'pelidnota',
#  'oncostman',
#  'palaeospondylus',
#  'semidiapason',
#  'spark',
#  'atrophied',
#  'subangulated',
#  'hemometry',
#  'thymelici',
#  'episternum',
#  'fritillary',
#  'incalculableness',
#  'trimargarin',
#  'chromatopathia',
#  'hanafite',
#  'lectorship',
#  'untired',
#  'xylographer',
#  'reel',
#  'vestibule',
#  'exhumation',
#  'epitrochoid',
#  'unappropriated',
#  'biotics',
#  'ungaudy',
#  'gynandria',
#  'chuckwalla',
#  'departmentize',
#  'archdeanery',
#  'beliked',
#  'cocksfoot',
#  'dunner',
#  'somniosus',
#  'unpriority',
#  'unyielded',
#  'volta',
#  'manchesterism',
#  'unsprung',
#  'wrester',
#  'enamel',
#  'historician',
#  'vomitable',
#  'momentous',
#  'horizontal',
#  'prefraternal',
#  'rheumed',
#  'alnaschar',
#  'histologic',
#  'salvationism',
#  'butterless',
#  'ploughtail',
#  'chondroitin',
#  'demivambrace',
#  'waringin',
#  'arillary',
#  'autophthalmoscope',
#  'extoller',
#  'lighttight',
#  'nonscoring',
#  'masthead',
#  'accomplished',
#  'interkinesis',
#  'moschatel',
#  'moldability',
#  'decerebrize',
#  'transporter',
#  'anolian',
#  'chromatogram',
#  'windwayward',
#  'gloam',
#  'dramaticule',
#  'hillward',
#  'conched',
#  'r',
#  'uncradled',
#  'creekfish',
#  'denotation',
#  'praefloration',
#  'potentness',
#  'unejaculated',
#  'internship',
#  'resorufin',
#  'gyroplane',
#  'tetrarchic',
#  'furthersome',
#  'condolement',
#  'asop',
#  'muriel',
#  'unfurnished',
#  'autodynamic',
#  'valiantly',
#  'brachypinacoid',
#  'rabbinship',
#  'noisomeness',
#  'pyrocondensation',
#  'citizeness',
#  'dansant',
#  'eternalness',
#  'carpopedal',
#  'sewen',
#  'wilsonian',
#  'bloodshed',
#  'tomboyism',
#  'compromission',
#  'talliage',
#  'unscared',
#  'unspongy',
#  'unluckily',
#  'biradiate',
#  'petling',
#  'tambookie',
#  'pantagruelize',
#  'irreplevisable',
#  'uncomposeable',
#  'overwove',
#  'ramaism',
#  'symbranchiate',
#  'tux',
#  'diuretically',
#  'irreportable',
#  'antilyssic',
#  'inoculum',
#  'bridestake',
#  'lanceolar',
#  'allogamy',
#  'stercoral',
#  'anglomaniac',
#  'odiometer',
#  'lastre',
#  'nais',
#  'hardystonite',
#  'parturience',
#  'unattuned',
#  'strangletare',
#  'owl',
#  'rostrulate',
#  'ravioli',
#  'justiciability',
#  'electromedical',
#  'iranism',
#  'boxing',
#  'treasonful',
#  'wanderable',
#  'permocarboniferous',
#  'splenatrophy',
#  'methodeutic',
#  'fiberizer',
#  'arrowheaded',
#  'trihalide',
#  'theology',
#  'cangle',
#  'hatmaking',
#  'endermatic',
#  'bubble',
#  'aknee',
#  'affair',
#  'goddessship',
#  'medrick',
#  'orographical',
#  'disprove',
#  'uncontractile',
#  'bail',
#  'lucban',
#  'slangish',
#  'anisopod',
#  'leukocidin',
#  'pseudozoogloeal',
#  'voe',
#  'theologicomoral',
#  'brittlewort',
#  'uncircumspectly',
#  'vagrom',
#  'pedary',
#  'bewired',
#  'monepic',
#  'orphange',
#  'neighboring',
#  'octolocular',
#  'renascibleness',
#  'cowitch',
#  'increasing',
#  'dryworker',
#  'commissioner',
#  'phlegmon',
#  'urbicolae',
#  'allurer',
#  'presciently',
#  'anisomyodous',
#  'staphylococcus',
#  'unfoliaged',
#  'unshyly',
#  'unridable',
#  'increscent',
#  'greeting',
#  'inexcitability',
#  'untransportable',
#  'arses',
#  'semidead',
#  'pyic',
#  'weighage',
#  'salpingion',
#  'orator',
#  'youward',
#  'bedframe',
#  'menominee',
#  'souplike',
#  'comnenian',
#  'unchemically',
#  'alose',
#  'philosophicalness',
#  'unprecluded',
#  'ceruleolactite',
#  'koreci',
#  'parvicellular',
#  'diethylenediamine',
#  'protectorless',
#  'syndrome',
#  'wid',
#  'pedaler',
#  'liquorish',
#  'biochemics',
#  'purohepatitis',
#  'uncock',
#  'demitoilet',
#  'unhallowedness',
#  'craniocerebral',
#  'nonproportional',
#  'protodramatic',
#  'filioque',
#  'preces',
#  'shovel',
#  'swinburnian',
#  'colpohysterotomy',
#  'trepanize',
#  'superconformable',
#  'talloel',
#  'crabber',
#  'disgenius',
#  'musical',
#  'committeeship',
#  'nonrequisition',
#  'probiology',
#  'ethnogeographic',
#  'coumaran',
#  'rugmaking',
#  'sicilienne',
#  'suppose',
#  'multangular',
#  'prehemiplegic',
#  'undepartableness',
#  'funambulation',
#  'rehumiliation',
#  'purpuroxanthin',
#  'cephalata',
#  'fivestones',
#  'pickpurse',
#  'nurhag',
#  'undeterminate',
#  'ceratohyal',
#  'unhumbugged',
#  'saprodontia',
#  'normless',
#  'peripherical',
#  'simulacre',
#  'brutification',
#  'loblolly',
#  'uncorruptibleness',
#  'restimulate',
#  'anacrisis',
#  'orthopyroxene',
#  'somatology',
#  'braille',
#  'meteoric',
#  'sayal',
#  'rover',
#  'charter',
#  'spadeful',
#  'abranchialism',
#  'unabolishable',
#  'ischiocavernosus',
#  'oleographic',
#  'misreflect',
#  'misguggle',
#  'globosite',
#  'chylosis',
#  'encloud',
#  'reales',
#  'doubter',
#  'tanklike',
#  'ambosexual',
#  'proctocolonoscopy',
#  'serpentinely',
#  'desmomyaria',
#  'agonothetic',
#  'penster',
#  'autoanalysis',
#  'confrication',
#  'seminary',
#  'uncanonized',
#  'visitative',
#  'jatki',
#  'antonio',
#  'pintle',
#  'besomer',
#  'touchingly',
#  'moorn',
#  'leachman',
#  'torrentfulness',
#  'macromesentery',
#  'gallowsness',
#  'heptanoic',
#  'anomural',
#  'overshadowingly',
#  'unfireproof',
#  'autoelevation',
#  'cnidian',
#  'deflorescence',
#  'hucksterer',
#  'lepidium',
#  'oversubtlety',
#  'isogenic',
#  'scaphism',
#  'subvestment',
#  'ungladly',
#  'sware',
#  'figurer',
#  'megasporic',
#  'pantographically',
#  'rhinoscopic',
#  'corresponsion',
#  'nonconciliating',
#  'superfervent',
#  'explosive',
#  'salt',
#  'loyal',
#  'perdition',
#  'chiffon',
#  'amentulum',
#  'fiot',
#  'fissiparous',
#  'trilli',
#  'molester',
#  'scroop',
#  'cotylosauria',
#  'stalagmometric',
#  'fullmouth',
#  'imperant',
#  'agglutinability',
#  'realty',
#  'inhomogeneity',
#  'grottolike',
#  'protoperlaria',
#  'hematotherapy',
#  'amygdalitis',
#  'backslapping',
#  'connature',
#  'sightful',
#  'oviducal',
#  'amassable',
#  'medianic',
#  'anophele',
#  'nongrass',
#  'capableness',
#  'sicilian',
#  'fluorosis',
#  'huey',
#  'crackiness',
#  'photographess',
#  'incogitable',
#  'presbyophrenic',
#  'rudolphus',
#  'heptarch',
#  'inequigranular',
#  'workman',
#  'caricography',
#  'rachiform',
#  'vinegarette',
#  'pulsate',
#  'zymometer',
#  'viscidly',
#  'insignificant',
#  'doublehorned',
#  'silicoflagellidae',
#  'pyrosulphuryl',
#  'castling',
#  'ruiner',
#  'bolometer',
#  'uninfallible',
#  'preambling',
#  'telokinesis',
#  'disoccupy',
#  'okshoofd',
#  'runtishly',
#  'outluster',
#  'stonehead',
#  'phrenopericardiac',
#  'countertechnicality',
#  'borne',
#  'nonforested',
#  'strippit',
#  'vesting',
#  'reversionable',
#  'dodecatoic',
#  'melinis',
#  'pilpul',
#  'refoundation',
#  'ileectomy',
#  'salamandrine',
#  'postcartilaginous',
#  'rand',
#  'puncticulate',
#  'ambilevous',
#  'garle',
#  'aerocolpos',
#  'starched',
#  'kidderminster',
#  'pampre',
#  'represcribe',
#  'amalgam',
#  'ridableness',
#  'parine',
#  'jugglery',
#  'cyanophile',
#  'anteroexternal',
#  'leucocytometer',
#  'oppugnance',
#  'carping',
#  'provision',
#  'oversweetness',
#  'anthropomancy',
#  'slavistic',
#  'whiteback',
#  'rectilineally',
#  'pathopsychology',
#  'hobbledehoyhood',
#  'chiripa',
#  'incisiform',
#  'ire',
#  'rhizotomy',
#  'autotypography',
#  'bequeath',
#  'gaussbergite',
#  'paraffinize',
#  'photochromotype',
#  'hackbush',
#  'tachinaria',
#  'transcendentalism',
#  'dispendiously',
#  'trismegist',
#  'recoveree',
#  'ligamentous',
#  'unoxidizable',
#  'heddler',
#  'hungeringly',
#  'misplace',
#  'phenosal',
#  'fluster',
#  'screaking',
#  'embryectomy',
#  'acronyc',
#  'succula',
#  'zebu',
#  'wisdom',
#  'unadjusted',
#  'indescribable',
#  'binal',
#  'tonsillitic',
#  'eruditely',
#  'palicourea',
#  'superoexternal',
#  'upsoak',
#  'signaturist',
#  'associative',
#  'archmediocrity',
#  'sulphopupuric',
#  'crocin',
#  'predebate',
#  'centgener',
#  'unhingement',
#  'polyphylety',
#  'scholarless',
#  'strepent',
#  'encoop',
#  'alkes',
#  'synoeciousness',
#  'adonai',
#  'allotropicity',
#  'cnidosis',
#  'hypoptyalism',
#  'dartingly',
#  'irradicable',
#  'refinedly',
#  'sonable',
#  'overflog',
#  'macrophoma',
#  'nonabsorbent',
#  'stability',
#  'possessingness',
#  'recidivism',
#  'tentative',
#  'prinker',
#  'frontager',
#  'bisection',
#  'goatherd',
#  'ephraimite',
#  'protomammal',
#  'nomothetes',
#  'reclear',
#  'abidingness',
#  'flaggish',
#  'misunderstander',
#  'pac',
#  'gonfalcon',
#  'qualify',
#  'thysel',
#  'turmoil',
#  'entifical',
#  'wistened',
#  'insertive',
#  'parachromophoric',
#  'pickman',
#  'tepee',
#  'recompact',
#  'superphlogisticate',
#  'enaliosaurian',
#  'umbeled',
#  'maculocerebral',
#  'uncoif',
#  'cristineaux',
#  'biolysis',
#  'blennuria',
#  'unspell',
#  'sorex',
#  'wirephoto',
#  'unvexed',
#  'deserter',
#  'attribute',
#  'anconagra',
#  'suaviloquence',
#  'granadilla',
#  'rerise',
#  'starbolins',
#  'algebraization',
#  'urtite',
#  'tantalofluoride',
#  'bandfish',
#  'unimprovedness',
#  'dorsigrade',
#  'servantship',
#  'workgirl',
#  'micrographist',
#  'gigantoblast',
#  'unlaudableness',
#  'tashie',
#  'crescentic',
#  'undissected',
#  'unstylishly',
#  'microcaltrop',
#  'nettling',
#  'saturate',
#  'pseudoskeletal',
#  'investigational',
#  'prezonal',
#  'although',
#  'plasterbill',
#  'oratoric',
#  'delaware',
#  'whalehead',
#  'gametogenous',
#  'semidomical',
#  'microcheilia',
#  'inguinocutaneous',
#  'phototelephony',
#  'blessedness',
#  'wristband',
#  'incompossible',
#  'fringillidae',
#  'photoesthesis',
#  'theosophistical',
#  'cold',
#  'digitigradism',
#  'pondwort',
#  'licorice',
#  'brachiolarian',
#  'negrophobiac',
#  'pagandom',
#  'noncaffeine',
#  'standpatter',
#  'sedgelike',
#  'chicote',
#  'linearization',
#  'limacine',
#  'reinform',
#  'xeronate',
#  'val',
#  'iritis',
#  'desmidiaceae',
#  'gan',
#  'mendelssohnian',
#  'dicyema',
#  'monochromically',
#  'vaginicolous',
#  'dispatch',
#  ...}

# %% [markdown]
# 8. 사용자가 입력한 단어의 끝 알파벳만 추출하는 함수를 작성하세요.

# %%
def get_last_char(word):
    return word.strip()[-1].lower()

# %% [markdown]
# 9. 입력받은 문자를 기반으로 단어 후보들을 생성한 뒤, nltk 사전으로 검증하는 함수를 작성하세요.

# %%
def get_candidate_words(start_char, used_words, max_trials=10):
    prompt = f"Give me an English word that starts with '{start_char}':"
    
    input_ids = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
        input_ids=input_ids.input_ids,
        max_new_tokens=10,
        num_return_sequences=max_trials,
        do_sample=True,
        temperature=0.9
    )
    candidates = set()

    for output in outputs:
        text = tokenizer.decode(output, skip_special_tokens=True)
        words_in_text = re.findall(r"\b[a-zA-Z]{3,}\b", text)
        for word in words_in_text:
            word_lower = word.lower()
            if word_lower.startswith(start_char) and word_lower in english_vocab and word_lower not in used_words:
                candidates.add(word_lower)
    return list(candidates)

    
print(get_candidate_words("banana", "", 10))
# Out:
# /Users/hannalee/Documents/코딩/huggingface-env/lib/python3.11/site-packages/transformers/pytorch_utils.py:338: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_elements = torch.tensor(test_elements)
# ['banana']

# %% [markdown]
# 10. 함수가 정상적으로 작동하는 것을 확인했으면, 끝말잇기 게임을 실행할 수 있는 함수를 작성해보세요.

# %%
def play_game(user_word, state):
    if state is None:
        state = {
            "used_words": set(),
            "score_user": 0,
            "score_bot": 0,
            "last_word": None,
            "game_over": False
        }
    
    if state["game_over"]:
        return "Game Over", state
    
    if not user_word or not re.match(r"^[a-zA-Z]{3,}$", user_word):
        return "Please enter a valid English word (3+ letters).", state
    
    user_word = user_word.strip().lower()
    if user_word in state["used_words"]:
        return f"You already used '{user_word}'. Try another word.", state
    
    if user_word not in english_vocab:
        return f"{user_word} is not in the dictionaray. Try another word.", state
    
    if state["last_word"]:
        expected_start = get_last_char(state["last_word"])
        if user_word[0] != expected_start:
            return f"Your word must start with '{expected_start}'.", state
        
    state["score_user"] += 1
    state["used_words"].add(user_word)
    last_char = get_last_char(user_word)
    candidates = get_candidate_words(last_char, state["used_words"])

    if not candidates:
        state["game_over"] = True
        return f"You: {user_word}\nBot: ...\nNo more vlid words found. You Win!\nFinal Score:\nYou: {state['score_user']}\nbot: {state['score_bot']}", state
    
    bot_word = candidates[0]
    state["used_words"].add(bot_word)
    state["score_bot"] += 1
    state["last_word"] = bot_word
    return (
        f"You: {user_word}\nBot: {bot_word}\n\n"
        f"Score:\nYou: {state['score_user']}  | Bot: {state['score_bot']}",
        state
    )

# %% [markdown]
# 11. 마지막으로 UI가 되어줄 Gradio 함수를 작성한 뒤, 게임이 정상적으로 실행되는지 테스트해보겠습니다.

# %%
# Gradio 인터페이스

iface = gr.Interface(
    fn=play_game,
    inputs=[
        gr.Textbox(label="Enter an English word"),
        gr.State()
    ],
    outputs=[
        gr.Textbox(label="Result"),
        gr.State()
    ],
    title = "English Word ChainvGame",
    description="Each word must start with the last letter of the previous word. No repeats"
)

iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/hannalee/Documents/코딩/huggingface-env/lib/python3.11/site-packages/transformers/pytorch_utils.py:338: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_elements = torch.tensor(test_elements)
# Created dataset file at: .gradio/flagged/dataset1.csv
# Error while flagging: Object of type set is not JSON serializable

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("✅ CUDA 사용 (GPU):", torch.cuda.get_device_name(0))
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("✅ MPS 사용 (Apple Silicon)")
else:
    device = torch.device("cpu")
    print("⚠️ GPU 미지원. CPU 사용 중.")

# %%
import torch

# 캐시된 메모리 비우기 (PyTorch 내부 캐시)
torch.cuda.empty_cache()

# 그래픽 카드가 비어 있는지 확인
print(torch.cuda.memory_summary(device=None, abbreviated=False))
